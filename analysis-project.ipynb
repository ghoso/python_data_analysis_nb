# %%
#
# 「Pythonによるデータ分析」チュートリアルプロジェクト
#
#from jupyterthemes import jtplot
#jtplot.style(theme='chesterish')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Titanic Challenge データ読み込み
# Kaggle https://kaggle.com/datasets
titanic = pd.read_csv('samples/datasets_11657_16098_train.csv',index_col=0)
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# 男女数
t_woman = titanic[titanic['Sex'] == 'female']
t_man = titanic[titanic['Sex'] == 'male']
len(t_woman.index)
# Out:
# 314

# %%
len(t_man.index)
# Out:
# 577

# %%
# 生存率
len(titanic[titanic['Survived'] == 1])/len(titanic)
# Out:
# 0.3838383838383838

# %%
# 年齢分布
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
survived = titanic[titanic['Survived'] == 1]
dead = titanic[titanic['Survived'] == 0]
labels=['Survived','Dead']
ax.hist([survived['Age'],dead['Age']],bins=10,label=labels)
ax.set_title('Titanic Casuality')
ax.set_xlabel('Age')
ax.set_ylabel('Number')
ax.legend()

# %%
# 男女比
dead_male = dead[dead['Sex'] == 'male']
dead_female = dead[dead['Sex'] == 'female']
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
labels = ['Male', 'Female']
ax.hist([dead_male['Age'], dead_female['Age']], bins=10, label=labels)
ax.set_title('Titanic Dead')
ax.set_xlabel('Age')
ax.set_ylabel('Number')
ax.legend()

# %%
# 株式データ分析
stock_data = pd.read_csv('samples/stock_px.csv')
stock_data.head()
# Out:
#             Unnamed: 0    AA  AAPL    GE    IBM   JNJ  MSFT   PEP     SPX  \
# 0  1990-02-01 00:00:00  4.98  7.86  2.87  16.79  4.27  0.51  6.04  328.79
# 1  1990-02-02 00:00:00  5.04  8.00  2.87  16.89  4.37  0.51  6.09  330.92
# 2  1990-02-05 00:00:00  5.07  8.18  2.87  17.32  4.34  0.51  6.05  331.85
# 3  1990-02-06 00:00:00  5.01  8.12  2.88  17.56  4.32  0.51  6.15  329.66
# 4  1990-02-07 00:00:00  5.04  7.77  2.91  17.93  4.38  0.51  6.17  333.75
#
#     XOM
# 0  6.12
# 1  6.24
# 2  6.25
# 3  6.23
# 4  6.33

# %%
# 銘柄別平均株価
stock_data.mean()
# Out:
# AA       17.440285
# AAPL     57.119313
# GE       17.933194
# IBM      66.637730
# JNJ      34.225340
# MSFT     17.046345
# PEP      34.284204
# SPX     945.035216
# XOM      35.225919
# dtype: float64

# %%
# 統計データ
stock_data.describe()
# Out:
#                 AA         AAPL           GE          IBM          JNJ  \
# count  5472.000000  5472.000000  5472.000000  5472.000000  5472.000000
# mean     17.440285    57.119313    17.933194    66.637730    34.225340
# std       9.647999    88.670423    10.647635    41.689481    19.726666
# min       4.200000     3.230000     2.400000     8.400000     4.200000
# 25%       8.077500     8.760000     6.280000    20.577500    12.160000
# 50%      14.885000    11.990000    18.150000    74.115000    37.570000
# 75%      26.340000    68.017500    27.300000    95.657500    52.675000
# max      43.620000   422.000000    42.780000   190.530000    67.320000
#
#               MSFT          PEP          SPX          XOM
# count  5472.000000  5471.000000  5472.000000  5472.000000
# mean     17.046345    34.284204   945.035216    35.225919
# std      11.000988    18.383894   369.494672    23.967647
# min       0.510000     5.870000   295.460000     5.940000
# 25%       4.240000    15.480000   547.217500    11.910000
# 50%      20.910000    33.750000  1058.305000    30.280000
# 75%      25.310000    49.530000  1253.395000    55.300000
# max      46.810000    71.250000  1565.150000    87.480000

# %%
# 株価チャート
no_spx = stock_data.drop('SPX', axis=1)
no_spx.plot()

# %%
# 政府統計　GDP
# e-Stat https://e-stat.go.jp
# ファイル名：gaku-mg2012-u.csv
# 単位；10億円
gdata1 = pd.read_csv('samples/gaku-mg2012-u.csv')
gdata1.head(10)
# Out:
#                       名目原系列                 Unnamed: 1          Unnamed: 2  \
# 0  Nominal, Original Series                        NaN                 NaN
# 1                       NaN                 国内総生産(支出側)            民間最終消費支出
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN  GDP(Expenditure Approach)  PrivateConsumption
# 5                       NaN                        NaN                 NaN
# 6               1994/ 1- 3.                 120,994.4            65,027.4
# 7                     4- 6.                 122,715.4            65,857.9
# 8                     7- 9.                 123,398.9            67,964.3
# 9                    10-12.                 134,429.0            69,592.0
#
#                  Unnamed: 3             Unnamed: 4  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                  家計最終消費支出                    NaN
# 3                       NaN             除く持ち家の帰属家賃
# 4  Consumption ofHouseholds  ExcludingImputed Rent
# 5                       NaN                    NaN
# 6                 64,414.0               55,816.1
# 7                 64,592.1               55,891.3
# 8                 66,824.0               58,010.2
# 9                 67,955.7               59,021.7
#
#                      Unnamed: 5                   Unnamed: 6  \
# 0                           NaN                          NaN
# 1                          民間住宅                       民間企業設備
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4  PrivateResidentialInvestment  Private Non-Resi.Investment
# 5                           NaN                          NaN
# 6                      5,984.4                     20,312.5
# 7                      6,320.7                     17,545.6
# 8                      7,386.7                     18,933.2
# 9                      6,956.1                     18,746.3
#
#                     Unnamed: 7             Unnamed: 8        Unnamed: 9  ...  \
# 0                          NaN                    NaN               NaN  ...
# 1                       民間在庫変動               政府最終消費支出          公的固定資本形成  ...
# 2                          NaN                    NaN               NaN  ...
# 3                          NaN                    NaN               NaN  ...
# 4  Changein PrivateInventories  GovernmentConsumption  PublicInvestment  ...
# 5                          NaN                    NaN               NaN  ...
# 6                    -2,480.9               17,358.4          12,191.5   ...
# 7                       820.6               20,182.0           9,672.2   ...
# 8                      -430.3               16,696.6          10,588.9   ...
# 9                     1,902.1               21,137.1          13,371.5   ...
#
#   Unnamed: 23                   Unnamed: 24 Unnamed: 25  \
# 0         NaN                           NaN         NaN
# 1         NaN                       総固定資本形成         NaN
# 2         NaN                           NaN         NaN
# 3         NaN                           NaN         NaN
# 4         NaN  Gross Fixed CapitalFormation         NaN
# 5         NaN                           NaN         NaN
# 6         NaN                     38,488.4          NaN
# 7         NaN                     33,538.5          NaN
# 8         NaN                     36,908.8          NaN
# 9         NaN                     39,074.0          NaN
#
#                          (単位:10億円)  Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 0                    (Billion Yen)          NaN         NaN         NaN
# 1                             最終需要          NaN         NaN         NaN
# 2                              NaN          NaN         NaN         NaN
# 3                              NaN          NaN         NaN         NaN
# 4  Final Sales of Domestic Product          NaN         NaN         NaN
# 5                              NaN          NaN         NaN         NaN
# 6                       123,588.9           NaN         NaN         NaN
# 7                       121,862.9           NaN         NaN         NaN
# 8                       123,715.2           NaN         NaN         NaN
# 9                       132,201.7           NaN         NaN         NaN
#
#   Unnamed: 30 Unnamed: 31  Unnamed: 32
# 0         NaN         NaN          NaN
# 1         NaN         NaN          NaN
# 2         NaN         NaN          NaN
# 3         NaN         NaN          NaN
# 4         NaN         NaN          NaN
# 5         NaN         NaN          NaN
# 6         NaN         NaN          NaN
# 7         NaN         NaN          NaN
# 8         NaN         NaN          NaN
# 9         NaN         NaN          NaN
#
# [10 rows x 33 columns]

# %%
# 余計なヘッダー削除、年月日をインデックス化
gdata2 = pd.read_csv('samples/gaku-mg2012-u.csv', skiprows=[0,1,3,4,5,6], index_col=0,thousands=',')
gdata2
# Out:
#              国内総生産(支出側)  民間最終消費支出  Unnamed: 3  Unnamed: 4    民間住宅   民間企業設備  \
# 1994/ 1- 3.    120994.4   65027.4     64414.0     55816.1  5984.4  20312.5
# 4- 6.          122715.4   65857.9     64592.1     55891.3  6320.7  17545.6
# 7- 9.          123398.9   67964.3     66824.0     58010.2  7386.7  18933.2
# 10-12.         134429.0   69592.0     67955.7     59021.7  6956.1  18746.3
# 1995/ 1- 3.    122207.9   66561.9     65914.3     56909.7  6275.5  20836.2
# ...                 ...       ...         ...         ...     ...      ...
# 2019/ 1- 3.    137430.9   75778.8     74187.2     61664.1  4132.7  25010.1
# 4- 6.          137783.3   75717.0     73803.9     61270.0  3993.8  20287.4
# 7- 9.          136299.8   76974.0     75029.1     62483.8  4429.4  22117.6
# 10-12.         142226.8   77307.3     74627.7     62067.8  4424.4  21025.8
# 2020/ 1- 3.    136249.0   74474.5     72627.0     60059.7  3996.9  24601.9
#
#              民間在庫変動  政府最終消費支出  公的固定資本形成  公的在庫変動  ...  Unnamed: 23  総固定資本形成  \
# 1994/ 1- 3. -2480.9   17358.4   12191.5  -113.7  ...          NaN  38488.4
# 4- 6.         820.6   20182.0    9672.2    31.8  ...          NaN  33538.5
# 7- 9.        -430.3   16696.6   10588.9   114.1  ...          NaN  36908.8
# 10-12.       1902.1   21137.1   13371.5   325.1  ...          NaN  39074.0
# 1995/ 1- 3. -2881.2   18337.4   11246.8   -46.4  ...          NaN  38358.5
# ...             ...       ...       ...     ...  ...          ...      ...
# 2019/ 1- 3. -1940.6   25922.7    7891.2     0.4  ...          NaN  37034.0
# 4- 6.        2042.6   29640.0    6028.8     1.4  ...          NaN  30310.0
# 7- 9.         -20.7   25891.1    7040.3   -11.5  ...          NaN  33587.3
# 10-12.       1211.5   29360.9    8317.6     5.5  ...          NaN  33767.8
# 2020/ 1- 3. -2323.2   26754.5    8220.9    18.8  ...          NaN  36819.8
#
#              Unnamed: 25      最終需要  Unnamed: 27  Unnamed: 28  Unnamed: 29  \
# 1994/ 1- 3.          NaN  123588.9          NaN          NaN          NaN
# 4- 6.                NaN  121862.9          NaN          NaN          NaN
# 7- 9.                NaN  123715.2          NaN          NaN          NaN
# 10-12.               NaN  132201.7          NaN          NaN          NaN
# 1995/ 1- 3.          NaN  125135.5          NaN          NaN          NaN
# ...                  ...       ...          ...          ...          ...
# 2019/ 1- 3.          NaN  139371.1          NaN          NaN          NaN
# 4- 6.                NaN  135739.3          NaN          NaN          NaN
# 7- 9.                NaN  136331.9          NaN          NaN          NaN
# 10-12.               NaN  141009.7          NaN          NaN          NaN
# 2020/ 1- 3.          NaN  138553.5          NaN          NaN          NaN
#
#              Unnamed: 30  Unnamed: 31  Unnamed: 32
# 1994/ 1- 3.          NaN          NaN          NaN
# 4- 6.                NaN          NaN          NaN
# 7- 9.                NaN          NaN          NaN
# 10-12.               NaN          NaN          NaN
# 1995/ 1- 3.          NaN          NaN          NaN
# ...                  ...          ...          ...
# 2019/ 1- 3.          NaN          NaN          NaN
# 4- 6.                NaN          NaN          NaN
# 7- 9.                NaN          NaN          NaN
# 10-12.               NaN          NaN          NaN
# 2020/ 1- 3.          NaN          NaN          NaN
#
# [105 rows x 32 columns]

# %%
# 余分なカラム削除
gdata3 = gdata2[[x for x in gdata2.columns if not x.startswith('Unnamed')]]
gdata3
# Out:
#              国内総生産(支出側)  民間最終消費支出    民間住宅   民間企業設備  民間在庫変動  政府最終消費支出  \
# 1994/ 1- 3.    120994.4   65027.4  5984.4  20312.5 -2480.9   17358.4
# 4- 6.          122715.4   65857.9  6320.7  17545.6   820.6   20182.0
# 7- 9.          123398.9   67964.3  7386.7  18933.2  -430.3   16696.6
# 10-12.         134429.0   69592.0  6956.1  18746.3  1902.1   21137.1
# 1995/ 1- 3.    122207.9   66561.9  6275.5  20836.2 -2881.2   18337.4
# ...                 ...       ...     ...      ...     ...       ...
# 2019/ 1- 3.    137430.9   75778.8  4132.7  25010.1 -1940.6   25922.7
# 4- 6.          137783.3   75717.0  3993.8  20287.4  2042.6   29640.0
# 7- 9.          136299.8   76974.0  4429.4  22117.6   -20.7   25891.1
# 10-12.         142226.8   77307.3  4424.4  21025.8  1211.5   29360.9
# 2020/ 1- 3.    136249.0   74474.5  3996.9  24601.9 -2323.2   26754.5
#
#              公的固定資本形成  公的在庫変動  財貨・サービス  海外からの所得     国民総所得      国内需要      民間需要  \
# 1994/ 1- 3.   12191.5  -113.7   2714.8   1222.1  122216.5  118279.6   88843.5
# 4- 6.          9672.2    31.8   2284.6   1210.9  123926.3  120430.8   90544.7
# 7- 9.         10588.9   114.1   2145.5    921.8  124320.8  121253.5   93853.9
# 10-12.        13371.5   325.1   2398.6    900.6  135329.6  132030.4   97196.6
# 1995/ 1- 3.   11246.8   -46.4   1877.6   1172.8  123380.7  120330.3   90792.5
# ...               ...     ...      ...      ...       ...       ...       ...
# 2019/ 1- 3.    7891.2     0.4    635.6   5794.4  143225.4  136795.3  102981.0
# 4- 6.          6028.8     1.4     72.2   4580.9  142364.2  137711.1  102040.9
# 7- 9.          7040.3   -11.5   -120.4   6233.1  142532.9  136420.2  103500.3
# 10-12.         8317.6     5.5    573.6   3427.2  145654.0  141653.1  103969.1
# 2020/ 1- 3.    8220.9    18.8    504.8   5694.0  141943.0  135744.3  100750.1
#
#                 公的需要  総固定資本形成      最終需要
# 1994/ 1- 3.  29436.2  38488.4  123588.9
# 4- 6.        29886.0  33538.5  121862.9
# 7- 9.        27399.5  36908.8  123715.2
# 10-12.       34833.8  39074.0  132201.7
# 1995/ 1- 3.  29537.8  38358.5  125135.5
# ...              ...      ...       ...
# 2019/ 1- 3.  33814.3  37034.0  139371.1
# 4- 6.        35670.2  30310.0  135739.3
# 7- 9.        32919.9  33587.3  136331.9
# 10-12.       37684.1  33767.8  141009.7
# 2020/ 1- 3.  34994.2  36819.8  138553.5
#
# [105 rows x 16 columns]

# %%
#  列の選択
gdata4 = gdata3[['国内総生産(支出側)','国民総所得','最終需要']]
gdata4
# Out:
#              国内総生産(支出側)     国民総所得      最終需要
# 1994/ 1- 3.    120994.4  122216.5  123588.9
# 4- 6.          122715.4  123926.3  121862.9
# 7- 9.          123398.9  124320.8  123715.2
# 10-12.         134429.0  135329.6  132201.7
# 1995/ 1- 3.    122207.9  123380.7  125135.5
# ...                 ...       ...       ...
# 2019/ 1- 3.    137430.9  143225.4  139371.1
# 4- 6.          137783.3  142364.2  135739.3
# 7- 9.          136299.8  142532.9  136331.9
# 10-12.         142226.8  145654.0  141009.7
# 2020/ 1- 3.    136249.0  141943.0  138553.5
#
# [105 rows x 3 columns]

# %%
# グラフ化
gdata5 = gdata4.rename(columns={'国内総生産(支出側)': 'GNP','国民総所得': 'GNI','最終需要': 'Total Demand'})
ax1 = gdata5.plot()
ax1.set_xlabel("Year/Month")
ax1.set_ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')
